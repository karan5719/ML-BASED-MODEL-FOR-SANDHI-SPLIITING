# %%
# encoding: utf-8
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate
import re

# List of valid Sanskrit characters in SLP1 notation
swaras = ['a', 'A', 'i', 'I', 'u', 'U', 'e', 'E', 'o', 'O', 'f', 'F', 'x', 'X']
vyanjanas = ['k', 'K', 'g', 'G', 'N', 
             'c', 'C', 'j', 'J', 'Y',
             'w', 'W', 'q', 'Q', 'R',
             't', 'T', 'd', 'D', 'n',
             'p', 'P', 'b', 'B', 'm',
             'y', 'r', 'l', 'v','S', 'z', 's', 'h', 'L', '|']
others = ['H', 'Z', 'V', 'M', '~', '/', '\\', '^', '\'']

slp1charlist = swaras + vyanjanas + others

# Function to remove unnecessary symbols from Devanagari text
def read_devnagri_text(text):
    symbols_to_remove = ['\u200c', '\u200d', '\ufeff', '\xad', '-', '–', '—', ' : ', '’', '“', '”', 
                         '!', '%', '&', '*', '+', '?', '/', ';', '{', '}', '=', ',', '\'', '"', 
                         '.', '॥', ')', '(', '[', ']', '<', '>', '`', '‘', '#', '।', '|']
    
    for symbol in symbols_to_remove:
        text = text.replace(symbol, '')

    text = re.sub('[0-9a-zA-Z०-९]', '', text)  # Remove English and Hindi numbers
    return text.strip()

# Function to remove characters not in SLP1
def remove_nonslp1_chars(word):
    return ''.join([char for char in word if char in slp1charlist])

# Function to process the Sandhi dataset
def get_sandhi_dataset(datafile, outputfile):
    word1list, word2list, outputlist = [], [], []
    
    with open(datafile, encoding="utf-8") as fp:
        lines = fp.read().splitlines()

    with open(outputfile, "w", encoding="utf-8") as outfile:
        for line in lines:
            if '=>' not in line:
                continue
            
            inout = line.split('=>')
            words = inout[1].split('+')

            if len(words) != 2:
                continue
            
            word1 = read_devnagri_text(words[0].strip())
            slp1word1 = remove_nonslp1_chars(transliterate(word1, sanscript.DEVANAGARI, sanscript.SLP1))
            
            word2 = read_devnagri_text(words[1].strip())
            slp1word2 = remove_nonslp1_chars(transliterate(word2, sanscript.DEVANAGARI, sanscript.SLP1))
            
            expected = read_devnagri_text(inout[0].strip())
            slp1expected = remove_nonslp1_chars(transliterate(expected, sanscript.DEVANAGARI, sanscript.SLP1))

            if slp1word1 and slp1word2 and slp1expected:
                word1list.append(slp1word1)
                word2list.append(slp1word2)
                outputlist.append(slp1expected)

                # Write output to file in the required format
                outfile.write(f"{slp1expected} => {slp1word1} + {slp1word2}\n")
                outfile.write(f"{expected} => {word1} + {word2}\n\n")

    return word1list, word2list, outputlist

# Function to get processed data and save output to a file
def get_xy_data(datafile, outputfile):
    w1l, w2l, ol = get_sandhi_dataset(datafile, outputfile)
    print(f"Processed data has been saved to {outputfile}")
    return w1l, w2l, ol

# File containing the Sandhi dataset
datafile = "sandhiset.txt"  # Make sure this file exists in your directory
outputfile = "converted_sandhi_output.txt"  # Output file for processed data

# Running the function and saving the output to a file
get_xy_data(datafile, outputfile)
# Out:
# Processed data has been saved to converted_sandhi_output.txt
# (['yasmAt',
#   'saH',
#   'svapitA',
#   'sUryodBavaH',
#   'SItaH',
#   'na',
#   'svaprakfteH',
#   'vEvaSyataH',
#   'kaH',
#   'na',
#   'tat',
#   'SarIre',
#   'nizprARaH',
#   'putraH',
#   'vayasA',
#   'vartamAnAH',
#   'anyAnizwacikIrzuH',
#   'saH',
#   'nAsikAm',
#   'kftrimatAm',
#   'vAcyaH',
#   'vartamAnaH',
#   'yaH',
#   'saH',
#   'jagati',
#   'jyAyAMsaH',
#   'jyezWAH',
#   'syuH',
#   "ko'pi",
#   'pUrtiH',
#   'AdO',
#   'saduHKAH',
#   'ataH',
#   'kasyacit',
#   'duHKinaH',
#   'tat',
#   'sparSaH',
#   'eva',
#   'sAraH',
#   'BUyaH',
#   'nEva',
#   'BAgyaSAlI',
#   'SrIH',
#   'kaYcit',
#   'bahiH',
#   'tat',
#   'bahiH',
#   'susTirAH',
#   'yat',
#   'tat',
#   'suhft',
#   'sahft',
#   'SAntaH',
#   'kalahaH',
#   'prakftiniyama',
#   'yataH',
#   'DEryAt',
#   'na',
#   'bahiH',
#   'gurUBaktAH',
#   'vidvacCradDAlavaH',
#   'vedavyAsaH',
#   'bfhat',
#   'saH',
#   'Bavet',
#   'DaninaH',
#   'yaSaH',
#   'tizWet',
#   'yat',
#   'kAmakroDAdayaH',
#   'mftAH',
#   'saH',
#   'praSAntaH',
#   'bahiH',
#   'janaH',
#   'vfttilABaH',
#   'mftaH',
#   'suKam',
#   'saH',
#   'yataH',
#   'kasyacit',
#   'Bavati',
#   'saH',
#   'bahiH',
#   'tasmAt',
#   'mahat',
#   'sAmAnyasya',
#   'na',
#   'BaNgaH',
#   'mA',
#   'tat',
#   'kaH',
#   'tataH',
#   'kfpaRaH',
#   'sarveSvaraH',
#   'tasya',
#   'bahiH',
#   'saH',
#   'pArvatISaNkarO',
#   'jAtaH',
#   'gfhAt',
#   'amitraH',
#   'kA',
#   'etat',
#   'punaH',
#   'Bagavat',
#   'pUrtiH',
#   'bahiH',
#   'saH',
#   'tat',
#   'yudapat',
#   'na',
#   'na',
#   'subudDimantaH',
#   'svayam',
#   'ISvaraH',
#   'tataH',
#   'tadicCApUrakaH',
#   'etat',
#   'punaH',
#   'yat',
#   'saH',
#   'etat',
#   'prakftiH',
#   'bahir',
#   'yat',
#   'tat',
#   'yat',
#   'tat',
#   'yat',
#   'tat',
#   'yataH',
#   'kintu',
#   'saH',
#   'SramaH',
#   'syAt',
#   'sAMsArikapadArTAH',
#   'tadA',
#   'ca',
#   'durDiyaH',
#   'parasya',
#   'janaH',
#   'sADusantaH',
#   'kAmAtmAnaH',
#   'pravartya',
#   'rucim',
#   'svArTAt',
#   'tat',
#   'na',
#   'svasya',
#   'etat',
#   'yataH',
#   'ugratAyAm',
#   'tyAjyaH',
#   'ca',
#   'sEnikAH',
#   'SAsakAH',
#   'mftAH',
#   'jIvitAH',
#   'SvaSrUH',
#   'santApayet',
#   'vaDUH',
#   'vidyAt',
#   'tat',
#   'Atmavat',
#   'saH',
#   'yaH',
#   'pakzavipakzataH',
#   'saH',
#   'nidritaH',
#   'yaH',
#   'BaktottamaH',
#   'svIyaH',
#   'SaktaH',
#   'santaH',
#   'santaH',
#   'sadyaH',
#   'yat',
#   'tataH',
#   'vayaH',
#   'sarvasya',
#   'priyaH',
#   'yat',
#   'saH',
#   'saH',
#   'yat',
#   'kAlaH',
#   'pratyutpannamateH',
#   'yaH',
#   'vAkCalataH',
#   'dUre',
#   'sumatimAn',
#   'vyaktiH',
#   'manaH',
#   'tat',
#   'bahiH',
#   'sahanIyaH',
#   'yaH',
#   'saH',
#   'avasaropayuktaH',
#   'saH',
#   'na',
#   'kasyacit',
#   'na',
#   'haritAni',
#   'saH',
#   'SramikaH',
#   'Bavitum',
#   'aByAsaH',
#   'pravIRaH',
#   'santi',
#   'yAtrA',
#   'tataH',
#   'tat',
#   'tat',
#   'pArSve',
#   'kadA',
#   'naSyet',
#   'budDiH',
#   'kiYcit',
#   'tat',
#   'milati',
#   'tat',
#   'tat',
#   'te',
#   'lABaH',
#   'tudati',
#   'kasyacit',
#   'kftaH',
#   'yAtrAyAm',
#   'punaH',
#   'yaH',
#   'miTaH',
#   'padayAtrAyAH',
#   'suhft',
#   'suhft',
#   'santAnaH',
#   'vAnarasvaBAvAH',
#   'grAmAt',
#   'BakzakAH',
#   'kevalam',
#   'svam',
#   'ISvaraH',
#   'guRayuktaH',
#   'sarvaH',
#   'kvacit',
#   'sAhAyyam',
#   'saH',
#   'sva',
#   'matyA',
#   'tat',
#   'kzatiH',
#   'asmat',
#   'leKakasya',
#   'kaH',
#   'pradattA',
#   'paranindAvacoBiH',
#   'kzIRaSaktiH',
#   'yaH',
#   'saH',
#   'yaH',
#   'saH',
#   'satsaNgaH',
#   'kartavyaH',
#   'tataH',
#   'bahiH',
#   'sva',
#   'niHspfhAH',
#   'svalpaH',
#   'Bavet',
#   'tat',
#   'dozaH',
#   'tat',
#   'yat',
#   'santyAjyam',
#   'tat',
#   'lokApavAdataH',
#   'kfpaRaH',
#   'kazwam',
#   'manaH',
#   'tat',
#   'tat',
#   'vEzRavasantaH',
#   'janaH',
#   'saH',
#   'yat',
#   'na',
#   'Palet',
#   'janatA',
#   'sa',
#   'SAsakAH',
#   'tadviSvAsaH',
#   'saH',
#   'jIvadByaH',
#   'nirmame',
#   'vilambaH',
#   'sadyaH',
#   'vilambAt',
#   'hAniH',
#   'pUrtiH',
#   'tat',
#   'budDimantaH',
#   'dfzwvA',
#   'samprArTayate',
#   'mahAkAlaH',
#   'hetuH',
#   'etat',
#   'vilambaH',
#   'na',
#   'nIrasam',
#   'cOraH',
#   'sarvakArAt',
#   'saH',
#   'bahiH',
#   'jaganmAtA',
#   'pravizwA',
#   'samupAsya',
#   'vimAtA',
#   'nEva',
#   'tasya',
#   'kaH',
#   'saH',
#   'prARAhutipradAne',
#   'SatruRA',
#   'tam',
#   'kiyat',
#   'saH',
#   'nEva',
#   'kiYcit',
#   'bfhat',
#   'vihAya',
#   'jalena',
#   'saH',
#   'keByaScit',
#   'yat',
#   'yuktyA',
#   'yuktyA',
#   'yuktibalena',
#   'bahiH',
#   'praSaMsAm',
#   'saH',
#   'etat',
#   'liptaH',
#   'saH',
#   'yaH',
#   'saH',
#   'nagarAt',
#   'vIraSivAjitulyAH',
#   'tat',
#   'etat',
#   'vipattO',
#   'saH',
#   'AgamanAt',
#   'tat',
#   'praTamaH',
#   'yaH',
#   'vaH',
#   'evam',
#   'parikramya',
#   'SabdaH',
#   'itaH',
#   'kutaH',
#   'samutTitaH',
#   'SrotravidAraRaH',
#   'balAhakAnAm',
#   'Ke',
#   'na',
#   'ezaH',
#   'hantum',
#   'tataH',
#   'sugrIvam',
#   'hariharO',
#   'hanumAn',
#   'itaH',
#   'matsAyakAt',
#   'tava',
#   'Bayam',
#   'mama',
#   'dfzwaH',
#   'saH',
#   'Kalu',
#   'devAnAm',
#   'rAjyam',
#   'punaH',
#   'muktaH',
#   'tava',
#   'Bettum',
#   'SfNgopamAn',
#   'DaraRIm',
#   'vigataBayAH',
#   'girim',
#   'vanAntarasya',
#   'sugrIvaHsamyak',
#   'karomi',
#   'pracalamahIDaram',
#   'sugrIvaHyad',
#   'aparADam',
#   'parityaktaH',
#   'tvatpAdaSuSrUzAm',
#   'kartum',
#   'sugrIvaH',
#   'sugrIvaH',
#   'vastram',
#   'kim',
#   'sugrIvam',
#   'tam',
#   'na',
#   'tad',
#   'SakraH',
#   'SatroH',
#   'SivaH',
#   'vizRuH',
#   'kartum',
#   'vAlISrUyatAm',
#   'AkfzyamARam',
#   'suvismitAH',
#   'tvam',
#   'BagnagrIvam',
#   'drutam',
#   'indraH',
#   'te',
#   'praBuH',
#   'maccakzuzpaTam',
#   'na',
#   'itaH',
#   'sugrIvaHyat',
#   'ezaH',
#   'muzwim',
#   'gAQam',
#   'vAnaraH',
#   'lakzmaRaHsugrIvam',
#   'paSyatu',
#   'harivaram',
#   'gurum',
#   'satAm',
#   'rAmam',
#   'vAnarendraH',
#   'durbalaH',
#   'patiH',
#   'sarvam',
#   'etat',
#   'Saram',
#   'ezaH',
#   'kAlalokam',
#   'DIram',
#   'SAntavegam',
#   'vAlImoham',
#   'rAmam',
#   'yuktam',
#   'narapatiDarmam',
#   'Calayitum',
#   'yaSasaH',
#   'prarUQam',
#   'yudDavyagrasya',
#   'pracCannaH',
#   'rAmaHkaTam',
#   'vaDaH',
#   'Kalu',
#   'vAgurAcCannam',
#   'mfgARAm',
#   'vaDyatvAt',
#   'mfgatvAt',
#   'BavAn',
#   'vAlIdaRqyaH',
#   'mAm',
#   'vAlIagamyAgamanena',
#   'yuktam',
#   'mfgam',
#   'na',
#   'guroH',
#   'daRqyaH',
#   'kadAcit',
#   'yavIyasaH',
#   'anuttarAH',
#   'rAmaHevam',
#   'gajendragAmin',
#   'patati',
#   'me',
#   'IdfSaH',
#   'saMvAryatAm',
#   'na',
#   'mAm',
#   'sugrIvaHyad',
#   'evam',
#   'hanUmAnyad',
#   'hanUmAn',
#   'itaH',
#   'harim',
#   'hanumAnezaH',
#   'SaranirBinnahfdayaH',
#   'guhaSaktisamAkrAntaH',
#   'vyaktam',
#   'kim',
#   'dozam',
#   'harIRAm',
#   'rozam',
#   'parigfhyatAm',
#   'sugrIvaHyat',
#   'kzantum',
#   'pratigfhyatAm',
#   'sugrIvaHanugfhItaH',
#   'ApaH',
#   'hanUmAnyat',
#   'imAH',
#   'parityajanti',
#   'mAm',
#   'mAm',
#   'sahasrahaMsaprayuktaH',
#   'netum',
#   'svaH',
#   'gataH',
#   'kriyatAm',
#   'sugrIvaHyad',
#   'sugrIvasya',
#   'praTamaH',
#   'dvitIyaH',
#   'kAryasya',
#   'prezitaH',
#   'kftopakArapratyupakAranimittam',
#   'vAnarAH',
#   'tezAm',
#   'kumArasya',
#   'pravfttim',
#   'ezaH',
#   'suKam',
#   'kutaH',
#   'mahArAjaH',
#   'kakuBaHkim',
#   'nizWatamarDam',
#   'kim',
#   'vfttAntam',
#   'vIryaprAbalyAt',
#   'sAgaraH',
#   'tasmAt',
#   'kumArapAdamUlam',
#   'Dik',
#   'Kalu',
#   'Kalu',
#   'udakaprasekaH',
#   'kiYcit',
#   'mAm',
#   'AryaputraH',
#   'mahendrapurI',
#   'etAm',
#   'rAjalakzmIm',
#   'vyApAdayitum',
#   'sarvataH',
#   'sarvam',
#   'vicitam',
#   'ca',
#   'vyarTaH',
#   'imam',
#   'praviSya',
#   'kanakaracitavidrumendranIlEH',
#   'SElAH',
#   'dfzwAH',
#   'dfzwAH',
#   'deSAH',
#   'dfzwAH',
#   'kaH',
#   'Kalu',
#   'sapraBaH',
#   'tAvat',
#   'Kalu',
#   'vidyulleKa',
#   'yA',
#   'maRiviracitamOliH',
#   'BAti',
#   'hariH',
#   'hariRInAm',
#   'kowarAntaritaH',
#   'vfttAntam',
#   'mAm',
#   'Druvam',
#   'UrDvam',
#   'ezaH',
#   'mama',
#   'pAdapamUlam',
#   'DyAnasaMvItahfdayA',
#   'svadeham',
#   'candraleKa',
#   'rAkzasIgaRaparivftA',
#   'yA',
#   'ca',
#   'Sriyam',
#   'mahatIm',
#   'na',
#   'vaSyatvam',
#   'iyam',
#   'mfgI',
#   'mAm',
#   'mAnuzam',
#   'kAmapaTAt',
#   'vacanagatasidDim',
#   'rAvaRasya',
#   'sumahat',
#   'ca',
#   'gatAyuH',
#   'rozam',
#   'kAryam',
#   'rAvaRam',
#   'kAryasidDiH',
#   'rakzaH',
#   'kAryam',
#   'kuvalayadAmaniBAm',
#   'daSaSirasam',
#   'Kalu',
#   'itaH',
#   'saparivAraH',
#   'nirgataH',
#   'suptAH',
#   'devIm',
#   'kowarAt',
#   'jayatu',
#   'kaH',
#   'vaYcayitukAmaH',
#   'alam',
#   'Srotum',
#   'tu',
#   'yaH',
#   'kaH',
#   'vfttAntaH',
#   'anaSanaparitaptam',
#   'manasijaSaradagDam',
#   'Dik',
#   'Kalu',
#   'virahapariSramaH',
#   'saMvfttaH',
#   'Aryaputrasya',
#   'pariSramam',
#   'ca',
#   'dolAyate',
#   'tvayA',
#   'saMgamaH',
#   'vAlinam',
#   'ca',
#   'sarvAH',
#   'tvAm',
#   'IdfSam',
#   'Kalu',
#   'rAmaH',
#   'vftaH',
#   'svapnaH',
#   'gAQam',
#   'BartAram',
#   'dehAntaram',
#   'ayam',
#   'patim',
#   'tava',
#   'SokaparavaSaH',
#   'vfttAntam',
#   'hanUmAnyad',
#   'kAryasidDiH',
#   'hanUmAnanugfhItaH',
#   'toyadABam',
#   'rAkzaseSam',
#   'dvitIyaH',
#   'tftIyaH',
#   'SaNkukarRaHkaH',
#   'kaH',
#   'aham',
#   'kim',
#   'nivedyatAm',
#   'yasyAm',
#   'priyamaRqana',
#   'snehAt',
#   'pallavAn',
#   'punaH',
#   'yasyAm',
#   'malayAnilAH',
#   'karEH',
#   'SakraripoH',
#   'BagnA',
#   'kim',
#   'kAryam',
#   'nivedyatAm',
#   'iyam',
#   'SaNkukarRaHpurataH',
#   'eva',
#   'yaH',
#   'yaTA',
#   'yaTAnirdizwaH',
#   'kaTam',
#   'navavAkyavAdin',
#   'SIGram',
#   'ca',
#   'pariDarzitaH',
#   'kenacit',
#   'sasaMramBam',
#   'vAnareRa',
#   'nigfhya',
#   'SaNkukarRaHyad',
#   'jagattrayaBItikftaH',
#   'saH',
#   'mfRAlavat',
#   'BagnaH',
#   'pARitalAByAm',
#   'nAdena',
#   'balam',
#   'SaNkukarRaHyad',
#   'kzipram',
#   'hatAH',
#   'kiNkarAH',
#   'hatAH',
#   'SaNkukarRaHyad',
#   'kumAraH',
#   'kftAstraH',
#   'SUraH',
#   'balavAn',
#   'ca',
#   'tam',
#   'rAvaRaHkim',
#   'SaNkukarRaHSrotum',
#   'mahArAjena',
#   'api',
#   'rAvaRaHtataH',
#   'BItaH',
#   'toraRam',
#   'kAYcanapariGam',
#   'nipAtitAH',
#   'rAvaRaHtataH',
#   'kumAram',
#   'paramalaGutaram',
#   'kapiH',
#   'muditataramuKaH',
#   'nirjaGAna',
#   'BasmIkaromi',
#   'nihatam',
#   'jYAyatAm',
#   'SaNkukarRaHyad',
#   'rAvaRaHkumAraH',
#   'kftAstraH',
#   'avaSyam',
#   'vaDaH',
#   'vijayaH',
#   'taTA',
#   'yudDam',
#   'saH',
#   'SIGram',
#   'rAvaRaHkaH',
#   'badDaH',
#   'kaH',
#   'rAkzasaHyad',
#   'rAvaRaHtvam',
#   'vAnaram',
#   'SaNkukarRayad',
#   'trElokyam',
#   'yat',
#   'sAkam',
#   'punaH',
#   'Saptam',
#   'tAByAm',
#   'tat',
#   'dIyatAm',
#   'suhfdAm',
#   'ehi',
#   'ezaH',
#   'nirviRRam',
#   'tvAm',
#   'viBIzaRaHnirvedaH',
#   'svAminam',
#   'rAvaRaHCidyatAm',
#   'tvam',
#   'vAnaram',
#   'viBIzaRaHyad',
#   'itaH',
#   'DarzitaH',
#   'kim',
#   'tvam',
#   'viBIzaRaHprazwum',
#   'kaH',
#   'mArutasya',
#   'kim',
#   'rAvaRaHkim',
#   'kim',
#   'SrUyatAm',
#   'sarvAparADezu',
#   'kartum',
#   'kim',
#   'saH',
#   'varaSaraRam',
#   'SaNkaram',
#   'rasAtalam',
#   'dEtyendrAH',
#   'kaTam',
#   'mAnuzaH',
#   'hanUmAnevam',
#   'pracCannam',
#   'dArApaharaRam',
#   'viBIzaRaHsamyak',
#   'rAmam',
#   'vipakzapakzam',
#   'hitam',
#   'pradIyatAm',
#   'kulam',
#   'na',
#   'kaTam',
#   'siMhaH',
#   'gajaH',
#   'nAma',
#   'lANgUlam',
#   'SaNkukarRaHyad',
#   'itaH',
#   'hanUmAnayam',
#   'mad',
#   'saH',
#   'aBiBUtaH',
#   'dArApaharaRAd',
#   'te',
#   'dIyatAm',
#   'raRaH',
#   'hanUmAnacirAt',
#   'raGuvarakArmukanAdanirjitaH',
#   'rAkzasAHitaH',
#   'nizkrAntaH',
#   'kAcit',
#   'hitam',
#   'vayam',
#   'sItApaharaRam',
#   'kaH',
#   'viBIzaRaHaDarmaH',
#   'sAvaSezam',
#   'tat',
#   'viBIzaRaHtad',
#   'kim',
#   'satyam',
#   'dAtum',
#   'rAvaRaHdattam',
#   'viBIzaRaHbalavadvigrahaH',
#   'balavadvigrahaH',
#   'Satrupakzam',
#   'kaH',
#   'mama',
#   'Satrupakzam',
#   'na',
#   'aham',
#   'rozam',
#   'kAmam',
#   'kAryam',
#   'ayam',
#   'adya',
#   'rAmam',
#   'punaH',
#   'nirgataH',
#   'nagararakzAm',
#   'tftIyaH',
#   'caturTaH',
#   'sannAham',
#   'hanUmatA',
#   'Kalu',
#   'sItAyAH',
#   'balADyakzaHkim',
#   'kim',
#   'laNkAyAm',
#   'Darmasamayam',
#   'BfSaSokataptamanasaH',
#   'sannAham',
#   'yad',
#   'vAnaravAhinI',
#   'rAmaH',
#   'hanumAn',
#   'pfTusAnukuYjagahanAH',
#   'nadyaH',
#   'tIrRAH',
#   'citram',
#   'samprAptaH',
#   'velAtawam',
#   'ezaH',
#   'sajalajalaDarendranIlanIraH',
#   'kaTam',
#   'sajIvam',
#   'kartum',
#   'kutaH',
#   'rAkzasaH',
#   'iva',
#   'hutASanam',
#   'apramattAH',
#   'SElEH',
#   'rakzovaDArTam',
#   'vAnarendrAH',
#   'naH',
#   'rAmaHrAkzasaH',
#   'hanUmAnyad',
#   'prAptaH',
#   'kaTam',
#   'mAm',
#   'sTAtum',
#   'suraripoH',
#   'vakzyati',
#   'pariSaNkitam',
#   'rAmaH',
#   'aDaH',
#   'idam',
#   'yAvat',
#   'hanUmAnUrDvam',
#   'kaTam',
#   'SaraRArTam',
#   'rAmaHkaTam',
#   'SaraRAgataH',
#   'praveSyatAm',
#   'vaktukAmam',
#   'tvAm',
#   'praveSyatAm',
#   'mA',
#   'BaktAH',
#   'vivadamAnaH',
#   'pUrvam',
#   'praveSyatAm',
#   'kumAraH',
#   'saMvfttaH',
#   'lakzmaRaHjayatu',
#   'saMvfttaH',
#   'SaraRyam',
#   'adya',
#   'rAjan',
#   'viBIzaRaHanugfhItaH',
#   'tvadAgamanAt',
#   'sidDam',
#   'na',
#   'mArgam',
#   'visrazwum',
#   'evam',
#   'sahasA',
#   'pratihatavIciravam',
#   'nararUpam',
#   'kAryArTam',
#   'ayam',
#   'rUpam',
#   'svayam',
#   'namaH',
#   'kaH',
#   'Kalu',
#   'navakuvalayanIlaH',
#   'avanatam',
#   'kurvaMn',
#   'ayam',
#   'varuRaH',
#   'kartum',
#   'kopaH',
#   'SIGram',
#   'dAtum',
#   'varuRaHezaH',
#   'dviDABUtaH',
#   'gacCa',
#   'hanUmAnyad',
#   'kvacit',
#   'kvacit',
#   'kvacit',
#   'kvacit',
#   'kvacit',
#   'kvacit',
#   'kvacit',
#   'BagavatprasAdAd',
#   'rAmaciram',
#   'udaDijalagatA',
#   'nOH',
#   'sugrIvaHyad',
#   'evam',
#   'nIlaHyad',
#   'kramAt',
#   'vayam',
#   'devaH',
#   'praveSayatu',
#   'nIlaHyad',
#   'vAnarEH',
#   'BaRatam',
#   'yuvAm',
#   'AvAm',
#   'viBIzaRaHsAvaDAnam',
#   'rAvaRena',
#   'AvAm',
#   'AryasaMSrayArTam',
#   'kaTam',
#   'prARAntike',
#   'na',
#   'daRqam',
#   'mA',
#   'SAsanAt',
#   'vfdDiH',
#   'kzayaH',
#   'tasmAt',
#   'sarvaskanDAvAram',
#   'evam',
#   'nIlaHyad',
#   'rAmaHaBiDIyatAm',
#   'saH',
#   'drazwakAmaH',
#   'uBOyad',
#   'vayam',
#   'balam',
#   'viBIzaRaHyad',
#   'yaTA',
#   'caturTaH',
#   'paYcamaH',
#   'rAkzasakAYcukIyaHkaH',
#   'praviSyAnyaH',
#   'ayam',
#   'prAptasyedAnIm',
#   'calattaraNgAhataBImavelam',
#   'dArapradAnAt',
#   ...],
#  ['jAyate',
#   'api',
#   'iva',
#   'vahniH',
#   'Bavati',
#   'eva',
#   'tyAgaM',
#   'tasya',
#   'nahi',
#   'eva',
#   'BavadBiH',
#   'asmin',
#   'na',
#   'mAtA',
#   'api',
#   'te',
#   'nA',
#   'anyApaSakunaM',
#   'api',
#   'upASrayet',
#   'Bavati',
#   'vinASyatAm',
#   'AnandaH',
#   'laByatAm',
#   'atra',
#   'ca',
#   'laByAH',
#   'tatra',
#   'antaH',
#   'tAsAM',
#   'ante',
#   'tAH',
#   'tAsu',
#   'jantoH',
#   'tasya',
#   'nIqaM',
#   'jAtiviSezasya',
#   'asti',
#   'BagavadASrayaH',
#   'BUyaH',
#   'Apnoti',
#   'eva',
#   'api',
#   'darSayate',
#   'AgacCan',
#   'gfhItvA',
#   'niHsftya',
#   'BUtvA',
#   'liKitaM',
#   'atra',
#   'apfcCat',
#   'taM',
#   'taTA',
#   'yatra',
#   'agre',
#   'hi',
#   'udDarate',
#   'atra',
#   'eva',
#   'na',
#   'api',
#   'gaReSena',
#   'mahABAratam',
#   'eva',
#   'nityaM',
#   'Danam',
#   'tasya',
#   'DanaM',
#   'rocate',
#   'yasya',
#   'banDujanAH',
#   'tataH',
#   'modate',
#   'nirgamayat',
#   'cOrye',
#   'cOryakarmanivArakaH',
#   'api',
#   'Apnoti',
#   'mAnavaH',
#   'hi',
#   'vastu',
#   'eva',
#   'cOryakAraRAt',
#   'gataH',
#   'vfkzAt',
#   'AScaryaM',
#   'api',
#   'asmAt',
#   'astu',
#   'aDunA',
#   'aham',
#   'asti',
#   'tarhi',
#   'mriyatAM',
#   'api',
#   'agre',
#   'AgataH',
#   'tu',
#   'iva',
#   'hi',
#   'bahiH',
#   'jAyate',
#   'asti',
#   'api',
#   'ahaM',
#   'guRAn',
#   'na',
#   'AgatAH',
#   'udatarat',
#   'idAniM',
#   'eva',
#   'ucitA',
#   'ucitA',
#   'tAM',
#   'eva',
#   'api',
#   'tuzwaH',
#   'Bavet',
#   'dfzwvA',
#   'api',
#   'niyataM',
#   'eva',
#   'AkarRya',
#   'avatizWate',
#   'nirasArayat',
#   'tu',
#   'acCam',
#   'uktavAn',
#   'aham',
#   'AdiSat',
#   'api',
#   'hi',
#   'anyaH',
#   'mahAvyADinA',
#   'avaSyaM',
#   'ca',
#   'hi',
#   'AsaktO',
#   'upahasyate',
#   'janAH',
#   'asmin',
#   'jAtu',
#   'mahAtmAnaH',
#   'Bavanti',
#   'anyAn',
#   'anyasya',
#   'vijYApyate',
#   'nUnaM',
#   'atra',
#   'eva',
#   'vatsa',
#   'janaH',
#   'api',
#   'hi',
#   'api',
#   'yudDe',
#   'tataH',
#   'divaM',
#   'iha',
#   'BUtvA',
#   'na',
#   'tarhi',
#   'na',
#   'guRAkfzwahfdayA',
#   'eva',
#   'asti',
#   'hi',
#   'anantAn',
#   'vindati',
#   'api',
#   'japet',
#   'nAsti',
#   'eva',
#   'na',
#   'tu',
#   'hi',
#   'tat',
#   'icCanti',
#   'janAH',
#   'liNgaM',
#   'api',
#   'Bavet',
#   'gfhe',
#   'kiM',
#   'sanAtanaDarmasaBAyAH',
#   'gfhe',
#   'vArtAsu',
#   'uktiH',
#   'anayA',
#   'avaSyaM',
#   'avatizWeta',
#   'janaH',
#   'upaBuNkte',
#   'vARI',
#   'malinaM',
#   'niHsftam',
#   'na',
#   'anyAyaM',
#   'asti',
#   'yaH',
#   'kiM',
#   'anizwaM',
#   'cintyaM',
#   'api',
#   'api',
#   'eva',
#   'DImAn',
#   'arhati',
#   'atra',
#   'ati',
#   'eva',
#   'AyAnti',
#   'yAnti',
#   'ahaM',
#   'Bavati',
#   'asti',
#   'api',
#   'na',
#   'tadA',
#   'samayAnantaram',
#   'DanaM',
#   'acCam',
#   'asmin',
#   'gfhaM',
#   'eva',
#   'gAlidAnena',
#   'alam',
#   'brAhmaRasya',
#   'atIva',
#   'aparigrahaH',
#   'ca',
#   'anyasmE',
#   'anizwaM',
#   'tayoH',
#   'pUrvam',
#   'api',
#   'anukurvIta',
#   'na',
#   'bahiH',
#   'yatra',
#   'ISvaraH',
#   'ISvaraM',
#   'tena',
#   'cet',
#   'Bavati',
#   'vyarTaM',
#   'Acaret',
#   'deyaH',
#   'izwAni',
#   'eva',
#   'nEva',
#   'Bavet',
#   'ASritAH',
#   'atra',
#   'dozaH',
#   'iyaM',
#   'na',
#   'viDIyatAm',
#   'vijAnAti',
#   'hi',
#   'na',
#   'kaTaM',
#   'na',
#   'asO',
#   'Bavati',
#   'viSrAmaM',
#   'AcaraRe',
#   'tataH',
#   'api',
#   'BUri',
#   'nEva',
#   'na',
#   'ahaM',
#   'Bavet',
#   'eva',
#   'AcaraRaM',
#   'BItaH',
#   'jAyate',
#   'Avindan',
#   'tIrTasnAnena',
#   'dalaM',
#   'dalaM',
#   'hi',
#   'vetti',
#   'vikaroti',
#   'icCasi',
#   'Idfk',
#   'nahi',
#   'icCati',
#   'icCati',
#   'tasyAH',
#   'na',
#   'aDigacCati',
#   'api',
#   'aDvani',
#   'nEva',
#   'viDIyatAm',
#   'jAyate',
#   'tasyAH',
#   'asamBavA',
#   'AnIyatAM',
#   'mahAjanAH',
#   'anyezAM',
#   'ISvaram',
#   'na',
#   'hi',
#   'AkarRya',
#   'na',
#   'ApamAnayet',
#   'eva',
#   'na',
#   'ca',
#   'kim',
#   'AgacCan',
#   'iva',
#   'asti',
#   'eva',
#   'api',
#   'aBivarzati',
#   'antikam',
#   'api',
#   'paritrAtuM',
#   'api',
#   'api',
#   'avaSyaM',
#   'dUre',
#   'vEPalyaM',
#   'Apnoti',
#   'dUraM',
#   'rASiM',
#   'anyat',
#   'eva',
#   'SAmyati',
#   'dineByaH',
#   'ekena',
#   'eva',
#   'eva',
#   'eva',
#   'vfkzopari',
#   'anyataH',
#   'svahastena',
#   'na',
#   'yaH',
#   'eva',
#   'taTA',
#   'eva',
#   'bahiH',
#   'te',
#   'vastu',
#   'mlecCarAjyam',
#   'api',
#   'kAryaM',
#   'BItaH',
#   'DanaM',
#   'aNkaH',
#   'gADiputramaKaviGnakarABihantA',
#   'niSicarendrakulABihantA',
#   'AryamiSrAn',
#   'avalokya',
#   'iva',
#   'itaH',
#   'nu',
#   'DvaniH',
#   'mahAn',
#   'iva',
#   'aBigarjatAm',
#   'avagacCasi',
#   'Kalu',
#   'samudyogaH',
#   'etO',
#   'rAmalakzmaRO',
#   'iva',
#   'ca',
#   'itaH',
#   'nihataBinnavikIrRadehaM',
#   'adya',
#   'tyaja',
#   'api',
#   'tvayA',
#   'vAlI',
#   'Aryasya',
#   'api',
#   'ASaNke',
#   'vAnarARAm',
#   'deva',
#   'adya',
#   'na',
#   'SrIDara',
#   'gatvA',
#   'hi',
#   'aBigacCa',
#   'aBitaH',
#   'Aha',
#   'ahaM',
#   'nflokam',
#   'AjYApayati',
#   'anuddiSya',
#   'tvayA',
#   'sugrIvaH',
#   'icCati',
#   'iti',
#   'iti',
#   'aninditANgi',
#   'asi',
#   'adya',
#   'paSya',
#   'Agamizyati',
#   'amAtyavargeRa',
#   'vA',
#   'me',
#   'vA',
#   'vA',
#   'arhati',
#   'matparAkramaH',
#   'avalokya',
#   'te',
#   'aByantaram',
#   'karomi',
#   'upagamya',
#   'vA',
#   'astu',
#   'vA',
#   'AsAdya',
#   'eva',
#   'itaH',
#   'AjYApayati',
#   'vAlI',
#   'kftvA',
#   'udvfttadaMzwraH',
#   'BAti',
#   'api',
#   'AryaH',
#   'upayAti',
#   'aBiBUya',
#   'vihAya',
#   'upagamya',
#   'tu',
#   'ca',
#   'mama',
#   'AryeRa',
#   'anuzWIyate',
#   'muktvA',
#   'vAlI',
#   'vivikzuH',
#   'AkarzamARaH',
#   'SarIram',
#   'upagamya',
#   'uddiSya',
#   'Bo',
#   'AsTitena',
#   'akrameRa',
#   'BAjanena',
#   'ayaSaH',
#   'aDarmyaH',
#   'vaDaH',
#   'aDarmyaH',
#   'iti',
#   'etat',
#   'ASritya',
#   'izyate',
#   'ca',
#   'ca',
#   'Cannena',
#   'iti',
#   'BavAn',
#   'iti',
#   'BoH',
#   'uddiSya',
#   'eva',
#   'mama',
#   'asmi',
#   'jyezWasya',
#   'dArABimarSanam',
#   'vayam',
#   'astu',
#   'tava',
#   'iva',
#   'adya',
#   'lokaDarmaH',
#   'strIjanaH',
#   'arhati',
#   'drazwum',
#   'AjYApayati',
#   'kriyatAm',
#   'jYApayati',
#   'ca',
#   'itaH',
#   'fkzagaReSvaram',
#   'mahArAjaH',
#   'viBAti',
#   'yaTA',
#   'utsfjya',
#   'aBilazasi',
#   'apAsya',
#   'aDipena',
#   'parigfhya',
#   'naH',
#   'AjYApayati',
#   'arhasi',
#   'asmatkulaDanaM',
#   'asmi',
#   'tAvat',
#   'AjYApayati',
#   'ApaH',
#   'iva',
#   'prARAH',
#   'aBigatAH',
#   'vIravAhI',
#   'AgataH',
#   'yAtaH',
#   'vAlI',
#   'asya',
#   'AjYApayati',
#   'aBizekaH',
#   'aNkaH',
#   'aNkaH',
#   'AhAravyApftAH',
#   'asmi',
#   'sarvAsu',
#   'AgatAH',
#   'dakziRApaTamuKyasya',
#   'aNgadasya',
#   'jYAtvA',
#   'AryakakuBaH',
#   'Aryasya',
#   'BavAn',
#   'ca',
#   'na',
#   'kAryasya',
#   'kim',
#   'rAmapatnyAH',
#   'laNGitaH',
#   'adya',
#   'AgacCa',
#   'eva',
#   'atiDIrA',
#   'asmi',
#   'adya',
#   'iva',
#   'hfdayaprasAdaH',
#   'antareRa',
#   'Bavet',
#   'iva',
#   'prApya',
#   'anuttamAm',
#   'udyataH',
#   'gatvA',
#   'BoH',
#   'na',
#   'eva',
#   'me',
#   'praviSya',
#   'avalokya',
#   'vikftamahAdrumapaNkticitradeSA',
#   'ca',
#   'mayA',
#   'mayA',
#   'ca',
#   'mayA',
#   'nu',
#   'etasmin',
#   'iva',
#   'avalokayAmi',
#   'iyam',
#   'iva',
#   'ezA',
#   'cArutAmrAyatAkzI',
#   'asO',
#   'iva',
#   'antare',
#   'BUtvA',
#   'jYAsyAmi',
#   'avivekinI',
#   'aho',
#   'avalokya',
#   'candramAH',
#   'aBipIqya',
#   'ASritya',
#   'anaSanakzAmavadanA',
#   'iva',
#   'iva',
#   'upavizwA',
#   'ezA',
#   'eva',
#   'ca',
#   'imAm',
#   'eva',
#   'AgatA',
#   'sA',
#   'iva',
#   'BAmini',
#   'adya',
#   'nivfttam',
#   'api',
#   'avalepaH',
#   'DanuH',
#   'api',
#   'iti',
#   'DArayitum',
#   'sADayAmi',
#   'hanmi',
#   'Bavizyati',
#   'mahat',
#   'vipadyate',
#   'vimucya',
#   'manasA',
#   'ayaM',
#   'mahArAjaH',
#   'rAvaRaH',
#   'rAvaRaH',
#   'ca',
#   'upasarpitum',
#   'avaruhya',
#   'aviDavA',
#   'nu',
#   'Bavet',
#   'anyaSaNkayA',
#   'arhati',
#   'aham',
#   'vA',
#   'vA',
#   'Aryaputrasya',
#   'pARqu',
#   'bAzpaparyAkulAkzam',
#   'vrIqitA',
#   'asmi',
#   'api',
#   'iti',
#   'asmin',
#   'ca',
#   'antare',
#   'iva',
#   'Aryaputrasya',
#   'jAtaH',
#   'Ahave',
#   'api',
#   'diSaH',
#   'devi',
#   'iva',
#   'ISvarAH',
#   'hi',
#   'vAnarasenayA',
#   'mayA',
#   'parijYAya',
#   'BartfvatsalA',
#   'gatA',
#   'idAnIm',
#   'iha',
#   'AnayAmi',
#   'na',
#   'BaRa',
#   'AjYApayati',
#   'Bavatu',
#   'asmi',
#   'trikUwam',
#   'karomi',
#   'aNkaH',
#   'aNkaH',
#   'iha',
#   'iha',
#   'vijayA',
#   'kriyatAm',
#   'mahArAjAya',
#   'na',
#   'api',
#   'lumpati',
#   'na',
#   'vIjanti',
#   'BayAt',
#   'api',
#   'aspfzwabAladrumAH',
#   'aSokavanikA',
#   'iti',
#   'etat',
#   'idam',
#   'nivedyatAm',
#   'nivedayAmi',
#   'vilokya',
#   'aBivartate',
#   'ezaH',
#   'arkaH',
#   'rAvaRaH',
#   'Bo',
#   'SfRomi',
#   'vada',
#   'adya',
#   'aham',
#   'vAnareRa',
#   'aBimfditASokavanikA',
#   'iti',
#   'Anaya',
#   'AjYApayati',
#   'api',
#   'vAnaraH',
#   'utpAwitAH',
#   'dAruparvatakaH',
#   'aBimfditAni',
#   'eva',
#   'AjYApaya',
#   'AjYApayati',
#   'eva',
#   'tena',
#   'drumayoDinA',
#   'iti',
#   'AjYApayati',
#   'hi',
#   'ca',
#   'ca',
#   'api',
#   'api',
#   'vanOkasam',
#   'arTam',
#   'arhati',
#   'anAjYApitA',
#   'anugatAH',
#   'tataH',
#   'iva',
#   'ASritya',
#   'udyamya',
#   'tena',
#   'tataH',
#   'akzam',
#   'bARajAlAn',
#   'api',
#   'muzwinA',
#   'iti',
#   'asmat',
#   'SrutvA',
#   'vfttAntaH',
#   'AjYApayati',
#   'hi',
#   'ca',
#   'yuDi',
#   'vA',
#   'aTavA',
#   'api',
#   'kumArasya',
#   'vAnaraH',
#   'badDaH',
#   'atra',
#   'iti',
#   'atra',
#   'AjYApayati',
#   'api',
#   'Anaya',
#   'AjYApayati',
#   'AjO',
#   'mayA',
#   'Akampya',
#   'agasutayA',
#   'ca',
#   'yadi',
#   'mama',
#   'iti',
#   'SokakAraRAt',
#   'ehi',
#   'upaviSAmi',
#   'iva',
#   'lakzaye',
#   'eva',
#   'upASritasya',
#   'ezA',
#   'api',
#   'Anaya',
#   'AjYApayati',
#   'itaH',
#   'tena',
#   'asya',
#   'avagacCasi',
#   'arhati',
#   'tvam',
#   'OrasaH',
#   'Srutam',
#   'Srutena',
#   'Aha',
#   'rAmaSAsanam',
#   'avaDyAH',
#   'arhati',
#   'Aha',
#   'mAnuzaH',
#   'upehi',
#   'vA',
#   'vA',
#   'mama',
#   'aBiyAti',
#   'mAm',
#   'viDena',
#   'tasya',
#   'kftam',
#   'Aha',
#   'tvayA',
#   'avalambase',
#   'me',
#   'rAGavaDarmapatnI',
#   'rAkzasapuNgavena',
#   'icCAmi',
#   'lambasawaH',
#   'mfgeRa',
#   'vA',
#   'aBiDatte',
#   'AdIpya',
#   'AjYApayati',
#   'itaH',
#   'asmi',
#   'vacanAt',
#   'mAnuzaH',
#   'mayA',
#   'asi',
#   'asti',
#   'me',
#   'mahAn',
#   'drakzyasi',
#   'tvam',
#   'itaH',
#   'hanumAn',
#   'vivakzA',
#   'antareRa',
#   'api',
#   'eva',
#   'dozaH',
#   'ca',
#   'iva',
#   'brUhi',
#   'eva',
#   'gUhase',
#   'na',
#   'arhati',
#   'aBayam',
#   'ca',
#   'nAma',
#   'upASritya',
#   'atra',
#   'anavekzya',
#   'upASritam',
#   'utsahe',
#   'eva',
#   'ca',
#   'ca',
#   'taTA',
#   'idAnIm',
#   'eva',
#   'hi',
#   'udDarizye',
#   'viBIzaRaH',
#   'sampAdayAmi',
#   'aNkaH',
#   'aNkaH',
#   'AjYApaya',
#   'AnItaH',
#   'AryarAmasya',
#   'vfttAntaH',
#   'iti',
#   'iti',
#   'kila',
#   'saMkleSyamAnA',
#   'rAmasya',
#   'AjYApitA',
#   'AjYApayati',
#   'iti',
#   'lakzmaRaH',
#   'ca',
#   'meGopamAH',
#   'ca',
#   'mayA',
#   'mahat',
#   'asmi',
#   'sAmpratam',
#   'BagavAn',
#   'vilulitaPenataraNgacAruhAraH',
#   'BoH',
#   'adya',
#   'nivArayati',
#   'nu',
#   'asO',
#   'ASu',
#   'pravezwum',
#   'Bavantu',
#   'drumEH',
#   'yuDi',
#   'tizWantu',
#   'narendram',
#   'iti',
#   'AjYApayati',
#   'asmi',
#   'nu',
#   'avagacCet',
#   'surEH',
#   'yuDi',
#   'iti',
#   'me',
#   'viSudDamanasA',
#   'avalokya',
#   'raGukulavfzaBasya',
#   'avatarAmi',
#   'avalokya',
#   'tatraBavAn',
#   'upAgataH',
#   'viBIzaRaH',
#   'iti',
#   'viBIzaRaH',
#   'iva',
#   'lakzye',
#   'viBIzaRaH',
#   'evam',
#   'taTA',
#   'api',
#   'pure',
#   'viBIzaRaH',
#   'lakzmaRaH',
#   'asmi',
#   'AryaH',
#   'asmi',
#   'SaraRAgataH',
#   'asmi',
#   'tvaddarSanavikalmazaH',
#   'asmi',
#   'eva',
#   'asmatkAryam',
#   'aDigamyate',
#   'na',
#   'arhati',
#   'tAvat',
#   'uttizWan',
#   'karomi',
#   'upASritasya',
#   'aByupagatasya',
#   'BagavAn',
#   'AsTAya',
#   'kAraRaBUtaH',
#   'Bagavate',
#   'nu',
#   'ezaH',
#   'mattamAtaNgalIlaH',
#   'iva',
#   'tejasA',
#   'Kalu',
#   'ayam',
#   'arhati',
#   'rozeRa',
#   'narottama',
#   'arhati',
#   'mArgaH',
#   'iva',
#   'agrataH',
#   'AjYApayati',
#   'api',
#   'SaNKAkIrRaH',
#   'api',
#   'vIcImAlaH',
#   'api',
#   'BImAvartaH',
#   'api',
#   'atItaH',
#   'vilokya',
#   'iva',
#   'vipannA',
#   'AjYApayati',
#   'kriyatAm',
#   'AjYApayati',
#   'niveSyamAnAsu',
#   'na',
#   'tasmAt',
#   'etO',
#   'AjYApayati',
#   'gfhyamARO',
#   'kO',
#   'BaRatam',
#   'Aryakumudasya',
#   'SukasAraRO',
#   'etO',
#   'Kalu',
#   'vAnararUpeRa',
#   'iva',
#   'api',
#   'eva',
#   'AjYApayatu',
#   'evam',
#   'eva',
#   'Bavizyati',
#   'vA',
#   'etO',
#   'praviSya',
#   'kriyatAm',
#   'AjYApayati',
#   'madvacanAt',
#   'rAkzasendraH',
#   'raRAtiTiH',
#   'AjYApayati',
#   'api',
#   'parIkzizyAmahe',
#   'AjYApayati',
#   'eva',
#   'aNkaH',
#   'aNkaH',
#   'iha',
#   'rAkzasaH',
#   'asmi',
#   'api',
#   'udIrRanakrAkulanIlanIram',
#   'na',
#   ...],
#  ['yasmAjjAyate',
#   "so'pi",
#   'svapiteva',
#   'sUryodBavovahniH',
#   'SItoBavati',
#   'nEva',
#   'svaprakftestyAgaM',
#   'vEvaSyatastasya',
#   'konahi',
#   'nEva',
#   'tadBavadBiH',
#   "SarIre'smin",
#   'nizprARona',
#   'putromAtA',
#   "vayasA'pi",
#   'varttamAnAste',
#   'anyAnizwacikIrzurnA',
#   "so'nyApaSakunaM",
#   'nAsikAmapi',
#   'kftrimatAmupASrayet',
#   'vAcyoBavati',
#   'vartamAnovinASyatAm',
#   'yaAnandaH',
#   'salaByatAm',
#   'jagatyatra',
#   'jyAyAMsaSca',
#   'jyezWAlaByAH',
#   'syustatra',
#   "ko'pyantaH",
#   'pUrtistAsAM',
#   'AdAvante',
#   'saduHKAstA',
#   'atastAsu',
#   'kasyacijjantoH',
#   'duHKinastasya',
#   'tannIqaM',
#   'sparSojAtiviSezasya',
#   'evAsti',
#   'sAroBagavadASrayaH',
#   'BUyoBUyaH',
#   'nEvApnoti',
#   'BAgyaSAlyeva',
#   'SrIrapi',
#   'kaYciddarSayate',
#   'bahirAgacCan',
#   'tadgfhItvA',
#   'bahirniHsftya',
#   'susTirABUtvA',
#   'yadliKitaM',
#   'tadatra',
#   'suhfdapfcCat',
#   'sahfdtaM',
#   'SAntistaTA',
#   'kalahoyatra',
#   'prakftiniyamAgre',
#   'yatohi',
#   'DEryAdudDarate',
#   'nAtra',
#   'bahiHeva',
#   'gurUBaktAna',
#   "vidvacCradDAlavo'pi",
#   'vedavyAsogaReSena',
#   'bfhadmahABAratam',
#   'saeva',
#   'BavennityaM',
#   'DaninoDanam',
#   'yaSastasya',
#   'tizWedDanaM',
#   'yadrocate',
#   'kAmakroDAdayoyasya',
#   'mftAbanDujanAH',
#   'satataH',
#   'praSAntomodate',
#   'bahirnirgamayat',
#   'janaScOrye',
#   'vfttilABaScOryakarmanivArakaH',
#   "mfto'pi",
#   'suKamApnoti',
#   'samAnavaH',
#   'yatohi',
#   'kasyacidvastu',
#   'Bavatyeva',
#   'sacOryakAraRAt',
#   'bahirgataH',
#   'tasmAdvfkzAt',
#   'mahadAScaryaM',
#   'sAmAnyasyApi',
#   'nAsmAt',
#   "BaNgo'stu",
#   "mA'DunA",
#   'tadaham',
#   "ko'sti",
#   'tatastarhi',
#   'kfpaRomriyatAM',
#   "sarveSvaro'pi",
#   'tasyAgre',
#   'bahirAgataH',
#   'satu',
#   'pArvatISaNkarAviva',
#   'jAtohi',
#   'gfhAdbahiH',
#   'amitrojAyate',
#   'kAsti',
#   'etadapi',
#   'punarahaM',
#   'BagavadguRAn',
#   'pUrtirna',
#   'bahirAgatAH',
#   'saudatarat',
#   'tadidAniM',
#   'yudapadeva',
#   'nocitA',
#   'nocitA',
#   'subudDimantastAM',
#   'svayameva',
#   "ISvaro'pi",
#   'tatastuzwaH',
#   'tadicCApUrakoBavet',
#   'etaddfzwvA',
#   'punarapi',
#   'yanniyataM',
#   'saeva',
#   'etadAkarRya',
#   'prakftiravatizWate',
#   'bahirnirasArayat',
#   'yattu',
#   'tadacCam',
#   'yaduktavAn',
#   'tadaham',
#   'yadAdiSat',
#   'tadapi',
#   'yatohi',
#   'kintvanyo',
#   'samahAvyADinA',
#   "Sramo'vaSyaM",
#   'syAcca',
#   'sAMsArikapadArTAhi',
#   'tadAsaktO',
#   'copahasyate',
#   'durDiyojanAH',
#   'parasyAsmin',
#   'janojAtu',
#   'sADusantomahAtmAnaH',
#   'kAmAtmAnoBavanti',
#   'pravartyAnyAn',
#   'rucimanyasya',
#   'svArTAdvijYApyate',
#   'tannUnaM',
#   'nAtra',
#   'svasyEva',
#   'etadvatsa',
#   'yatojanaH',
#   'ugratAyAmapi',
#   'tyAjyohi',
#   'cApi',
#   'sEnikAyudDe',
#   'SAsakAstataH',
#   'mftAdivaM',
#   'jIvitAiha',
#   'SvaSrUrBUtvA',
#   'santApayenna',
#   'vaDUstarhi',
#   'vidyAnna',
#   'tadguRAkfzwahfdayA',
#   'Atmavadeva',
#   "so'sti",
#   'yohi',
#   "pakzavipakzato'nantAn",
#   'savindati',
#   "nidrito'pi",
#   'yojapet',
#   'BaktottamonAsti',
#   'svIyaeva',
#   'Saktona',
#   'santastu',
#   'santohi',
#   'sadyastat',
#   'yadicCanti',
#   'tatojanAH',
#   'vayoliNgaM',
#   'sarvasyApi',
#   'priyoBavet',
#   'yadgfhe',
#   'sakiM',
#   'sasanAtanaDarmasaBAyAH',
#   'yadgfhe',
#   'kAlovArtAsu',
#   'pratyutpannamateruktiH',
#   "yo'nayA",
#   "vAkCalato'vaSyaM",
#   "dUre'vatizWeta",
#   'sumatimAYjanaH',
#   'vyaktirupaBuNkte',
#   'manovARI',
#   'tadmalinaM',
#   'bahirniHsftam',
#   'sahanIyona',
#   "yo'nyAyaM",
#   "so'sti",
#   'avasaropayuktoyaH',
#   'sakiM',
#   'nAnizwaM',
#   'kasyaciccintyaM',
#   'nApi',
#   'haritAnyapi',
#   'saeva',
#   'SramikoDImAn',
#   'Bavitumarhati',
#   "aByAso'tra",
#   "pravIRo'ti",
#   'santyeva',
#   "yatrA''yAnti",
#   'tatoyAnti',
#   'tadahaM',
#   'tadBavati',
#   "pArSve'sti",
#   'kadApi',
#   'naSyenna',
#   'budDistadA',
#   'kiYcitsamayAnantaram',
#   'tadDanaM',
#   'milatyacCam',
#   'tadasmin',
#   'tadgfhaM',
#   'taeva',
#   'lABogAlidAnena',
#   'tudatyalam',
#   'kasyacidbrAhmaRasya',
#   "kfto'tIva",
#   'yAtrAyAmaparigrahaH',
#   'punaSca',
#   "yo'nyasmE",
#   "miTo'nizwaM",
#   'padayAtrayAtayoH',
#   'suhfdpUrvam',
#   'suhfdapi',
#   "santAno'nukurvIta",
#   'vAnarasvaBAvAna',
#   'grAmAdbahiH',
#   'BakzakAyatra',
#   'kevalamISvaraH',
#   'svamISvaraM',
#   'ISvarastena',
#   'guRayuktaScet',
#   'sarvoBavati',
#   'kvacidvyarTaM',
#   'sAhAyyamAcaret',
#   'sadeyaH',
#   'svezwAni',
#   'matyEva',
#   'tannEva',
#   'kzatirBavet',
#   'asmadASritAH',
#   'leKakasyAtra',
#   'kodozo',
#   'pradatteyaM',
#   'paranindAvacoBirna',
#   'kzIRaSaktirviDIyatAm',
#   'yovijAnAti',
#   'sahi',
#   'yona',
#   'sakaTaM',
#   'satsaNgona',
#   "kartavyo'sO",
#   'tatoBavati',
#   'bahirviSrAmaM',
#   'svAcaraRe',
#   'niHspfhAstataH',
#   "svalpo'pi",
#   'BavedBUri',
#   'tadnEva',
#   'dozona',
#   'tadahaM',
#   'yadBavet',
#   'santyAjyameva',
#   'tadAcaraRaM',
#   'lokApavAdatoBItaH',
#   'kfpaRojAyate',
#   'kazwamAvindan',
#   'manastIrTasnAnena',
#   'taddalaM',
#   'taddalaM',
#   'vEzRavasantohi',
#   'janovetti',
#   'savikaroti',
#   'yadicCasi',
#   'nedfk',
#   'Palennahi',
#   'janatecCati',
#   'secCati',
#   'SAsakAstasyAH',
#   'tadviSvAsona',
#   "so'DigacCati",
#   "jIvadByo'pi",
#   "nirmame'Dvani",
#   'vilambonEva',
#   'sadyoviDIyatAm',
#   'vilambAjjAyate',
#   'hAnistasyAH',
#   'pUrtirasamBavA',
#   'tadAnIyatAM',
#   'budDimantomahAjanAH',
#   "dfzwvA'nyezAM",
#   'samprArTayataISvaram',
#   'mahAkAlona',
#   'heturhi',
#   'etadAkarRya',
#   'vilambona',
#   'nApamAnayet',
#   'nIrasameva',
#   'cOrona',
#   'sarvakArAcca',
#   'sakim',
#   'bahirAgacCan',
#   'jaganmAteva',
#   'pravizwAasti',
#   'samupAsyEva',
#   'vimAtApi',
#   'nEvABivarzati',
#   'tasyAntikam',
#   "ko'pi",
#   'saparitrAtuM',
#   "prARAhutipradAne'pi",
#   "SatruRA'pi",
#   'tamavaSyaM',
#   'kiyaddUre',
#   'savEPalyaM',
#   'nEvApnoti',
#   'kiYciddUraM',
#   'bfhadrASiM',
#   'vihAyAnyat',
#   'jalenEva',
#   'saSAmyati',
#   'keByaSciddineByaH',
#   'yadekena',
#   'yuktyEva',
#   'yuktyEva',
#   'yuktibalenEva',
#   'bahirvfkzopari',
#   'praSaMsAmanyataH',
#   'sasvahastena',
#   'etadna',
#   'liptoyaH',
#   'saeva',
#   'yastaTA',
#   'saeva',
#   'nagarAdbahiH',
#   'vIraSivAjitulyAste',
#   'tadvastu',
#   'etadmlecCarAjyam',
#   'vipattAvapi',
#   'sakAryaM',
#   'AgamanAdBItaH',
#   'tadDanaM',
#   "praTamo'NkaH",
#   'yogADiputramaKaviGnakarABihantA',
#   'voniSicarendrakulABihantA',
#   'evamAryamiSrAn',
#   'parikramyAvalokya',
#   'Sabdaiva',
#   'itaitaH',
#   'kutonu',
#   'samutTitoDvaniH',
#   'SrotravidAraRomahAn',
#   'balAhakAnAmiva',
#   "Ke'BigarjatAm",
#   'nAvagacCasi',
#   'ezaKalu',
#   'hantuMsamudyogaH',
#   'tataetO',
#   'sugrIvaMrAmalakzmaRO',
#   'hariharAviva',
#   'hanumAMSca',
#   'itaitaH',
#   'matsAyakAnnihataBinnavikIrRadehaM',
#   'tavAdya',
#   'BayaMtyaja',
#   'mamApi',
#   'dfzwastvayA',
#   'savAlI',
#   'KalvAryasya',
#   'devAnAmapi',
#   'rAjyamASaNke',
#   'punarvAnarARAm',
#   'muktodeva',
#   'tavAdya',
#   'BettuMna',
#   'SfNgopamAYCrIDara',
#   'DaraRIMgatvA',
#   'vigataBayAhi',
#   'girimaBigacCa',
#   'vanAntarasyABitaH',
#   'sugrIvaHsamyagAha',
#   'karomyahaM',
#   'pracalamahIDaraMnflokam',
#   'sugrIvaHyadAjYApayati',
#   'aparADamanuddiSya',
#   'parityaktastvayA',
#   'tvatpAdaSuSrUzAMsugrIvaH',
#   'kartumicCati',
#   'sugrIvaiti',
#   'sugrIvaiti',
#   'vastramaninditANgi',
#   'kimasi',
#   'sugrIvamadya',
#   'taMpaSya',
#   'nAgamizyati',
#   'tadamAtyavargeRa',
#   'SakrovA',
#   'Satrorme',
#   'SivovA',
#   'vizRurvA',
#   'kartumarhati',
#   'vAlISrUyatAMmatparAkramaH',
#   'mAkfzyamARamavalokya',
#   'suvismitAste',
#   'tvamaByantaram',
#   'BagnagrIvaMkaromi',
#   'drutamupagamya',
#   'indrovA',
#   "te'stu",
#   'praBurvA',
#   'maccakzuzpaTamAsAdya',
#   'nEva',
#   'itaitaH',
#   'sugrIvaHyadAjYApayati',
#   'ezavAlI',
#   'muzwiMkftvA',
#   'gAQamudvfttadaMzwraH',
#   'vAnaroBAti',
#   'lakzmaRaHsugrIvamapi',
#   'paSyatvAryaH',
#   'harivaramupayAti',
#   'gurumaBiBUya',
#   'satAMvihAya',
#   'rAmamupagamya',
#   'vAnarendrastu',
#   'durbalaSca',
#   'patirmama',
#   'sarvamAryeRa',
#   'etadanuzWIyate',
#   'SaraMmuktvA',
#   'ezavAlI',
#   'kAlalokaMvivikzuH',
#   'DIramAkarzamARaH',
#   'SAntavegaMSarIram',
#   'vAlImohamupagamya',
#   'rAmamuddiSya',
#   'yuktaMBo',
#   'narapatiDarmamAsTitena',
#   'CalayitumakrameRa',
#   'yaSasoBAjanena',
#   'prarUQamayaSaH',
#   'yudDavyagrasyADarmyaH',
#   'pracCannovaDaH',
#   'rAmaHkaTamaDarmyaH',
#   'vaDaiti',
#   'Kalvetat',
#   'vAgurAcCannamASritya',
#   'mfgARAmizyate',
#   'vaDyatvAcca',
#   'mfgatvAcca',
#   'BavAMSCannena',
#   'vAlIdaRqyaiti',
#   'mAMBavAn',
#   'vAlIagamyAgamaneneti',
#   'yuktaMBoH',
#   'mfgamuddiSya',
#   'nEva',
#   'gurormama',
#   "daRqyo'smi",
#   'kadAcijjyezWasya',
#   'yavIyasodArABimarSanam',
#   'anuttarAvayam',
#   'rAmaHevamastu',
#   'gajendragAmiMstava',
#   'patatIva',
#   "me'dya",
#   'IdfSolokaDarmaH',
#   'saMvAryatAMstrIjanaH',
#   'nArhati',
#   'mAMdrazwum',
#   'sugrIvaHyadAjYApayati',
#   'evaMkriyatAm',
#   'hanUmAnyadAjYApayati',
#   'hanUmAMSca',
#   'itaitaH',
#   'harimfkzagaReSvaram',
#   'hanumAnezamahArAjaH',
#   'SaranirBinnahfdayoviBAti',
#   'guhaSaktisamAkrAntoyaTA',
#   'vyaktamutsfjya',
#   'kimaBilazasi',
#   'dozamapAsya',
#   'harIRAmaDipena',
#   'rozaMparigfhya',
#   'parigfhyatAMnaH',
#   'sugrIvaHyadAjYApayati',
#   'kzantumarhasi',
#   'pratigfhyatAmasmatkulaDanaM',
#   "sugrIvaHanugfhIto'smi",
#   'ApastAvat',
#   'hanumAnyadAjYApayati',
#   'imAApaH',
#   'parityajantIva',
#   'mAMprARAH',
#   'mAmaBigatAH',
#   'sahasrahaMsaprayuktovIravAhI',
#   'netumAgataH',
#   'svaryAtaH',
#   'gatovAlI',
#   'kriyatAmasya',
#   'sugrIvaHyadAjYApayati',
#   'sugrIvasyABizekaH',
#   "praTamo'NkaH",
#   "dvitIyo'NkaH",
#   'kAryasyAhAravyApftAH',
#   "prezito'smi",
#   'kftopakArapratyupakAranimittaMsarvAsu',
#   'vAnarAAgatAH',
#   'tezAMdakziRApaTamuKyasya',
#   'kumArasyANgadasya',
#   'pravfttiMjYAtvA',
#   'ezaAryakakuBaH',
#   'suKamAryasya',
#   'kutoBavAn',
#   'mahArAjaSca',
#   'kakuBaHkiMna',
#   'nizWatamarDaMkAryasya',
#   'kiMkim',
#   'vfttAntaMrAmapatnyAH',
#   'vIryaprAbalyAllaNGitaH',
#   "sAgaro'dya",
#   'tasmAdAgacCa',
#   'kumArapAdamUlameva',
#   'DigatiDIrA',
#   'Kalvasmi',
#   'Kalvadya',
#   'udakaprasekaiva',
#   'kiYcidhfdayaprasAdaH',
#   'mAmantareRa',
#   'AryaputroBavet',
#   'mahendrapurIva',
#   'etAMprApya',
#   'rAjalakzmImanuttamAm',
#   'vyApAdayitumudyataH',
#   'sarvatogatvA',
#   'sarvaMBoH',
#   'vicitaMna',
#   'cEva',
#   'vyarTome',
#   'imaMpraviSya',
#   'praviSyAvalokya',
#   'kanakaracitavidrumendranIlErvikftamahAdrumapaNkticitradeSA',
#   'SElASca',
#   'dfzwAmayA',
#   'dfzwAmayA',
#   'deSASca',
#   'dfzwAmayA',
#   'konu',
#   'Kalvetasmin',
#   'sapraBaiva',
#   'tAvadavalokayAmi',
#   'Kalviyam',
#   'vidyulleKeva',
#   'yEzA',
#   'maRiviracitamOliScArutAmrAyatAkzI',
#   'BAtyasO',
#   'haririva',
#   'hariRInAmantare',
#   'kowarAntaritoBUtvA',
#   'vfttAntaMjYAsyAmi',
#   'mAmavivekinI',
#   'Druvamaho',
#   'UrDvamavalokya',
#   'ezacandramAH',
#   'mamABipIqya',
#   'pAdapamUlamASritya',
#   'DyAnasaMvItahfdayAnaSanakzAmavadanA',
#   'svadehamiva',
#   'candraleKeva',
#   'rAkzasIgaRaparivftopavizwA',
#   'yEzA',
#   'cEva',
#   'SriyaMca',
#   'mahatImimAm',
#   'nEva',
#   'vaSyatvamAgatA',
#   'iyaMsA',
#   'mfgIva',
#   'mAMBAmini',
#   'mAnuzamadya',
#   'kAmapaTAnnivfttam',
#   'vacanagatasidDimapi',
#   'rAvaRasyAvalepaH',
#   'sumahadDanuH',
#   'cApi',
#   'gatAyuriti',
#   'rozaMDArayitum',
#   'kAryaMsADayAmi',
#   'rAvaRaMhanmi',
#   'kAryasidDirBavizyati',
#   'rakzomahat',
#   'kAryaMvipadyate',
#   'kuvalayadAmaniBAMvimucya',
#   'daSaSirasaMmanasA',
#   'KalvayaM',
#   'itomahArAjaH',
#   'saparivArorAvaRaH',
#   'nirgatorAvaRaH',
#   'suptASca',
#   'devImupasarpitum',
#   'kowarAdavaruhya',
#   'jayatvaviDavA',
#   'konu',
#   'vaYcayitukAmoBavet',
#   'alamanyaSaNkayA',
#   'Srotumarhati',
#   'tvaham',
#   'yovA',
#   'kovA',
#   'vfttAntaAryaputrasya',
#   'anaSanaparitaptaMpARqu',
#   'manasijaSaradagDaMbAzpaparyAkulAkzam',
#   'DigvrIqitA',
#   'Kalvasmi',
#   "virahapariSramo'pi",
#   'saMvfttaiti',
#   'AryaputrasyAsmin',
#   'pariSramaMca',
#   'cAntare',
#   'dolAyataiva',
#   'tvayAryaputrasya',
#   'saMgamojAtaH',
#   'vAlinamAhave',
#   'cApi',
#   'sarvAdiSaH',
#   'tvAMdevi',
#   'IdfSamiva',
#   'KalvISvarA',
#   'rAmohi',
#   'vftovAnarasenayA',
#   'svapnomayA',
#   'gAQaMparijYAya',
#   'BartAraMBartfvatsalA',
#   'dehAntaraMgatA',
#   'ayamidAnIm',
#   'patimiha',
#   'tavAnayAmi',
#   'SokaparavaSona',
#   'vfttAntaMBaRa',
#   'hanUmAnyadAjYApayati',
#   'kAryasidDirBavatu',
#   "hanUmAnanugfhIto'smi",
#   'toyadABaMtrikUwam',
#   'rAkzaseSaMkaromi',
#   "dvitIyo'NkaH",
#   "tftIyo'NkaH",
#   'SaNkukarRaHkaiha',
#   'kaiha',
#   'ahaMvijayA',
#   'kiMkriyatAm',
#   'nivedyatAMmahArAjAya',
#   'yasyAMna',
#   'priyamaRqanApi',
#   'snehAllumpati',
#   'pallavAnna',
#   'punarvIjanti',
#   'yasyAMBayAt',
#   'malayAnilAapi',
#   'karEraspfzwabAladrumAH',
#   'SakrariporaSokavanikA',
#   'Bagneti',
#   'kimetad',
#   'kAryamidam',
#   'nivedyatAMnivedyatAm',
#   'iyaMnivedayAmi',
#   'SaNkukarRaHpuratovilokya',
#   'evABivartate',
#   'yaezaH',
#   'yaTArkaH',
#   'yaTAnirdizworAvaRaH',
#   'kaTaMBo',
#   'navavAkyavAdiYCfRomi',
#   'SIGraMvada',
#   'cAdya',
#   "pariDarzito'ham",
#   'kenacidvAnareRa',
#   'sasaMramBamaBimfditASokavanikA',
#   'vAnareReti',
#   'nigfhyAnaya',
#   'SaNkukarRaHyadAjYApayati',
#   "jagattrayaBItikfto'pi",
#   'savAnaraH',
#   'mfRAlavadutpAwitAH',
#   'BagnodAruparvatakaH',
#   'pARitalAByAmaBimfditAni',
#   'nAdenEva',
#   'balamAjYApaya',
#   'SaNkukarRaHyadAjYApayati',
#   'kziprameva',
#   'hatAstena',
#   'kiNkarAdrumayoDinA',
#   'hatAiti',
#   'SaNkukarRaHyadAjYApayati',
#   'kumArohi',
#   'kftAstraSca',
#   'SUraSca',
#   'balavAnapi',
#   'cApi',
#   'taMvanOkasam',
#   'rAvaRaHkimarTam',
#   'SaNkukarRaHSrotumarhati',
#   'mahArAjenAnAjYApitA',
#   'apyanugatAH',
#   'rAvaRaHtatastataH',
#   'BItaiva',
#   'toraRamASritya',
#   'kAYcanapariGamudyamya',
#   'nipAtitAstena',
#   'rAvaRaHtatastataH',
#   'kumAramakzaM',
#   'paramalaGutaraMbARajAlAn',
#   'kapirapi',
#   'muditataramuKomuzwinA',
#   'nirjaGAneti',
#   'BasmIkaromyasmat',
#   'nihataMSrutvA',
#   'jYAyatAMvfttAntaH',
#   'SaNkukarRaHyadAjYApayati',
#   'rAvaRaHkumArohi',
#   'kftAstraSca',
#   'avaSyaMyuDi',
#   'vaDovA',
#   "vijayo'TavA",
#   'taTApi',
#   'yudDaMkumArasya',
#   'savAnaraH',
#   'SIGraMbadDaH',
#   "rAvaRaHko'tra",
#   'badDaiti',
#   "ko'tra",
#   'rAkzasaHyadAjYApayati',
#   'rAvaRaHtvamapi',
#   'vAnaramAnaya',
#   'SaNkukarRayadAjYApayati',
#   'trElokyamAjO',
#   'yanmayA',
#   'sAkamAkampya',
#   'punaragasutayA',
#   'SaptaMca',
#   'tAByAMyadi',
#   'tanmama',
#   'dIyatAmiti',
#   'suhfdAMSokakAraRAt',
#   'ehyehi',
#   'ezaupaviSAmi',
#   'nirviRRamiva',
#   'tvAMlakzaye',
#   'viBIzaRaHnirvedaeva',
#   'svAminamupASritasya',
#   'rAvaRaHCidyatAmezA',
#   'tvamapi',
#   'vAnaramAnaya',
#   'viBIzaRaHyadAjYApayati',
#   'itaitaH',
#   'Darzitastena',
#   'kimasya',
#   'tvamavagacCasi',
#   'viBIzaRaHprazwumarhati',
#   'kastvam',
#   'mArutasyOrasaH',
#   'kiMSrutam',
#   'rAvaRaHkiMSrutena',
#   'kimAha',
#   'SrUyatAMrAmaSAsanam',
#   'sarvAparADezvavaDyAH',
#   'kartumarhati',
#   'kimAha',
#   'samAnuzaH',
#   'varaSaraRamupehi',
#   'SaNkaraMvA',
#   'rasAtalaMvA',
#   'dEtyendrAmama',
#   'kaTamaBiyAti',
#   'mAnuzomAma',
#   'hanUmAnevaMviDena',
#   'pracCannaMtasya',
#   'dArApaharaRaMkftam',
#   'viBIzaRaHsamyagAha',
#   'rAmaMtvayA',
#   'vipakzapakzamavalambase',
#   'hitaMme',
#   'pradIyatAMrAGavaDarmapatnI',
#   'kulaMrAkzasapuNgavena',
#   'necCAmi',
#   'kaTaMlambasawaH',
#   'siMhomfgeRa',
#   'gajovA',
#   'nAmABiDatte',
#   'lANgUlamAdIpya',
#   'SaNkukarRaHyadAjYApayati',
#   'itaitaH',
#   'hanUmAnayamasmi',
#   'madvacanAt',
#   'samAnuzaH',
#   'aBiBUtomayA',
#   'dArApaharaRAdasi',
#   "te'sti",
#   'dIyatAMme',
#   'raRomahAn',
#   'hanUmAnacirAddrakzyasi',
#   'raGuvarakArmukanAdanirjitastvam',
#   'rAkzasAHitaitaH',
#   'nizkrAntohanumAn',
#   'kAcidvivakzA',
#   'hitamantareRa',
#   'vayamapi',
#   'sItApaharaRameva',
#   'kodozaH',
#   'viBIzaRaHaDarmaSca',
#   'sAvaSezamiva',
#   'tadbrUhi',
#   'viBIzaRaHtadeva',
#   'kiMgUhase',
#   'satyaMna',
#   'dAtumarhati',
#   'rAvaRaHdattamaBayam',
#   'viBIzaRaHbalavadvigrahaSca',
#   'balavadvigrahonAma',
#   'SatrupakzamupASritya',
#   "ko'tra",
#   'mamAnavekzya',
#   'SatrupakzamupASritam',
#   'notsahe',
#   'ahameva',
#   'rozaMca',
#   'kAmaMca',
#   'kAryaMtaTA',
#   'ayamidAnIm',
#   'adyEva',
#   'rAmaMhi',
#   'punarudDarizye',
#   'nirgatoviBIzaRaH',
#   'nagararakzAMsampAdayAmi',
#   "tftIyo'NkaH",
#   "caturTo'NkaH",
#   'sannAhamAjYApaya',
#   'hanUmatAnItaH',
#   'KalvAryarAmasya',
#   'sItAyAvfttAntaH',
#   'balADyakzaHkimiti',
#   'kimiti',
#   'laNkAyAMkila',
#   'DarmasamayaMsaMkleSyamAnA',
#   'BfSaSokataptamanasorAmasya',
#   'sannAhamAjYApitA',
#   'yadAjYApayati',
#   'vAnaravAhinIti',
#   'rAmolakzmaRaH',
#   'hanumAMSca',
#   'pfTusAnukuYjagahanAmeGopamAH',
#   'nadyaSca',
#   'tIrRAmayA',
#   'citraMmahat',
#   "samprApto'smi",
#   'velAtawaMsAmpratam',
#   'ezaBagavAn',
#   'sajalajalaDarendranIlanIrovilulitaPenataraNgacAruhAraH',
#   'kaTaMBoH',
#   'sajIvamadya',
#   'kartuMnivArayati',
#   'kutonu',
#   "rAkzaso'sO",
#   'ivASu',
#   'hutASanaMpravezwum',
#   'apramattABavantu',
#   'SElErdrumEH',
#   'rakzovaDArTaMyuDi',
#   'vAnarendrAstizWantu',
#   'nonarendram',
#   'rAmaHrAkzasaiti',
#   'hanUmAnyadAjYApayati',
#   "prApto'smi",
#   'kaTaMnu',
#   'mAmavagacCet',
#   'sTAtuMsurEH',
#   'surariporyuDi',
#   'vakzyatIti',
#   'pariSaNkitaMme',
#   'rAmoviSudDamanasA',
#   "aDo'valokya",
#   'idaMraGukulavfzaBasya',
#   'yAvadavatarAmi',
#   'hanUmAnUrDvamavalokya',
#   'kaTaMtatraBavAn',
#   'SaraRArTamupAgataH',
#   'rAmaHkaTaMviBIzaRaH',
#   'SaraRAgataiti',
#   'praveSyatAMviBIzaRaH',
#   'vaktukAmamiva',
#   'tvAMlakzye',
#   'praveSyatAMviBIzaRaH',
#   'mEvaM',
#   'BaktAstaTA',
#   "vivadamAno'pi",
#   'pUrvaMpure',
#   'praveSyatAMviBIzaRaH',
#   'kumArolakzmaRaH',
#   "saMvftto'smi",
#   'lakzmaRaHjayatvAryaH',
#   "saMvftto'smi",
#   'SaraRyaMSaraRAgataH',
#   'adyAsmi',
#   'rAjaMstvaddarSanavikalmazaH',
#   "viBIzaRaHanugfhIto'smi",
#   'tvadAgamanAdeva',
#   'sidDamasmatkAryam',
#   'nADigamyate',
#   'mArgaMna',
#   'visrazwumarhati',
#   'evaMtAvat',
#   'sahasottizWan',
#   'pratihatavIciravaMkaromi',
#   'nararUpamupASritasya',
#   'kAryArTamaByupagatasya',
#   'ayaMBagavAn',
#   'rUpamAsTAya',
#   'svayaMkAraRaBUtaH',
#   'namoBagavate',
#   'konu',
#   'KalvezaH',
#   'navakuvalayanIlomattamAtaNgalIlaH',
#   'mavanatamiva',
#   'kurvaMstejasA',
#   'ayaMKalu',
#   "varuRo'yam",
#   'kartumarhati',
#   'koporozeRa',
#   'SIGraMnarottama',
#   'dAtumarhati',
#   'varuRaHezamArgaH',
#   'dviDABUtaiva',
#   'gacCAgrataH',
#   'hanUmAnyadAjYApayati',
#   'kvacidapi',
#   'kvacicCaNKAkIrRaH',
#   'kvacidapi',
#   'kvacidvIcImAlaH',
#   'kvacidapi',
#   'kvacidBImAvartaH',
#   'kvacidapi',
#   'BagavatprasAdAdatItaH',
#   'rAmaciraMvilokya',
#   'udaDijalagateva',
#   'nOrvipannA',
#   'sugrIvaHyadAjYApayati',
#   'evaMkriyatAm',
#   'nIlaHyadAjYApayati',
#   'kramAnniveSyamAnAsu',
#   'vayaMna',
#   'devastasmAt',
#   'praveSayatvetO',
#   'nIlaHyadAjYApayati',
#   'vAnarErgfhyamARO',
#   'BaRataMkO',
#   'yuvAMBaRatam',
#   'AvAmAryakumudasya',
#   'viBIzaRaHsAvaDAnaMSukasAraRO',
#   'rAvaRenEtO',
#   'AvAMKalu',
#   'AryasaMSrayArTaMvAnararUpeRa',
#   'kaTamiva',
#   "prARAntike'pi",
#   'nEva',
#   'daRqamAjYApayatu',
#   'mEvam',
#   'SAsanAdeva',
#   'vfdDirBavizyati',
#   'kzayovA',
#   'tasmAdetO',
#   'sarvaskanDAvAraMpraviSya',
#   'evaMkriyatAm',
#   'nIlaHyadAjYApayati',
#   'rAmaHaBiDIyatAMmadvacanAt',
#   'sarAkzasendraH',
#   'drazwakAmoraRAtiTiH',
#   'uBOyadAjYApayati',
#   'vayamapi',
#   'balaMparIkzizyAmahe',
#   'viBIzaRaHyadAjYApayati',
#   'yaTEva',
#   "caturTo'NkaH",
#   "paYcamo'NkaH",
#   'rAkzasakAYcukIyaHkaiha',
#   'praviSyAnyorAkzasaH',
#   'ayamasmi',
#   'prAptasyedAnImapi',
#   'calattaraNgAhataBImavelamudIrRanakrAkulanIlanIram',
#   'dArapradAnAnna',
#   ...])
